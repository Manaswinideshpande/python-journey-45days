# %%
# unordered so no indexing,no slicing,{item1,itemn},int,float,tuples,string. but not list dictno duplicates

# %%
employee_id = {12,34,56,78,90,90,90,"manu","puppy","pinky",(5,7,8)}
print(employee_id)
print(type(employee_id))
# Out:
# {'puppy', 34, 12, (5, 7, 8), 78, 'pinky', 'manu', 56, 90}
# <class 'set'>

# %%
set1 =set()
print(type(set1))
set1
# Out:
# <class 'set'>
# set()

# %% [markdown]
# ### set2 = {}
# ### print(type(set2))
# ### <class 'dict'>

# %% [markdown]
# ADD

# %%
voterlistset = {"padmini","varshini","rukmini","haindavai"}
voterlistset.add("python")
voterlistset
# Out:
# {'haindavai', 'padmini', 'python', 'rukmini', 'varshini'}

# %% [markdown]
# clear

# %%
voterlistset.clear()

# %%
voterlistset
# Out:
# set()

# %%
sample1= {"padmini","varshini","rukmini","haindavai"}
sample2 = sample1.copy() 
sample1.add("python")

print(sample1)
print(sample2)
# Out:
# {'python', 'padmini', 'haindavai', 'varshini', 'rukmini'}
# {'varshini', 'rukmini', 'haindavai', 'padmini'}

# %%
sample1.pop()
# Out:
# 'padmini'

# %%
sample1.remove('varshini')

# %%
sample1
# Out:
# {'haindavai', 'rukmini'}

# %% [markdown]
# update

# %%
voterlist= {"nandini","priya","kalyani","madhu", "madhumathi"}
newdata ={"padmini","tanuja","veeran","rathod"}
voterlist.update(newdata)
voterlist
# Out:
# {'kalyani',
#  'madhu',
#  'madhumathi',
#  'nandini',
#  'padmini',
#  'priya',
#  'rathod',
#  'tanuja',
#  'veeran'}

# %%
dict1 = {"name":"manu","height":5,"language":"telugu"}

# %%
dict1['height']
# Out:
# 5

# %%
dict1.get('height')
# Out:
# 5
