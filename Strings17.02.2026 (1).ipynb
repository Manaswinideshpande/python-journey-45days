# %%
##Strings are immutable/NTS,1space = 1char

# %%
strings='hello python'
strings
# Out:
# 'hello python'

# %%
sample =""
print(type(sample))
# Out:
# <class 'str'>

# %%
#var[indexvalue]
my_string ='python hai'
print(my_string[0])
print(my_string[1])
print(my_string[2])
print(my_string[3])
print(my_string[4])
print(my_string[5])
print(my_string[6])# empty space
print(my_string[7])
# Out:
# p
# y
# t
# h
# o
# n
#
# h

# %%
# slicing - start.stop.step
my_string ='python hai'
print(my_string[2:6])
# Out:
# thon

# %%
print(my_string[-8:-4])
# Out:
# thon

# %%
print(my_string[10:6:-1])
# Out:
# iah

# %%
print(my_string[-1:-4:-1])
# Out:
# iah

# %%
print(my_string[::-1])
# Out:
# iah nohtyp

# %%
print(my_string[-1:-11:-1])
# Out:
# iah nohtyp

# %% [markdown]
# upper lower

# %%
my_string.upper()
# Out:
# 'PYTHON HAI'

# %%
my_string.lower()
# Out:
# 'python hai'

# %% [markdown]
# count

# %%
my_string.count('h')
# Out:
# 2

# %% [markdown]
# Strip

# %%
string1 = " Hi my name is manu  and i am  ai enthussiast    "
print(len(string1))
result = string1.strip()
print(len(result))
result
# Out:
# 49
# 44
# 'Hi my name is manu  and i am  ai enthussiast'

# %%
string1 = " Hi my name is manu  and i am  ai enthussiast    "
print(len(string1))
result = string1.lstrip()
print(len(result))
result
# Out:
# 49
# 48
# 'Hi my name is manu  and i am  ai enthussiast    '

# %%
string1 = " Hi my name is manu  and i am  ai enthussiast    "
print(len(string1))
result = string1.rstrip()
print(len(result))
result
# Out:
# 49
# 45
# ' Hi my name is manu  and i am  ai enthussiast'

# %% [markdown]
# split

# %%
string1 = "Hi, my name is manu,and i am  ai enthussiast"  
result=string1.split(',')

# %%
result
# Out:
# ['Hi', ' my name is manu', 'and i am  ai enthussiast']

# %%
type(result)
# Out:
# list

# %% [markdown]
# replace

# %%
original = """artificial intelligence (AI), the ability of a digital computer or computer-controlled robot
to perform tasks commonly associated with intelligent beings. The term is frequently applied to the project of developing systems
endowed with the intellectual processes characteristic of humans, such as the ability to reason, discover meaning, generalize,
or learn from past experience. Since their development in the 1940s, digital computers have been programmed to carry out very complex tasks—such
as discovering proofs for mathematical theorems or playing chess—with great proficiency. Despite continuing advances in computer processing speed 
and memory capacity, there are as yet no programs that can match full human flexibility over wider domains or in tasks requiring much everyday knowledge.
On the other hand, some programs have attained the performance levels of human experts and professionals in executing certain specific tasks, 
so that artificial intelligence in this limited sense is found in applications as diverse as medical diagnosis, computer search engines,
voice or handwriting recognition, and chatbots."""

# %%
result = original.replace('the','da')

# %%
result
# Out:
# 'artificial intelligence (AI), da ability of a digital computer or computer-controlled robot\nto perform tasks commonly associated with intelligent beings. The term is frequently applied to da project of developing systems\nendowed with da intellectual processes characteristic of humans, such as da ability to reason, discover meaning, generalize,\nor learn from past experience. Since dair development in da 1940s, digital computers have been programmed to carry out very complex tasks—such\nas discovering proofs for madamatical daorems or playing chess—with great proficiency. Despite continuing advances in computer processing speed \nand memory capacity, dare are as yet no programs that can match full human flexibility over wider domains or in tasks requiring much everyday knowledge.\nOn da odar hand, some programs have attained da performance levels of human experts and professionals in executing certain specific tasks, \nso that artificial intelligence in this limited sense is found 
# ...

# %% [markdown]
# starts_with ends_with

# %%
text ="hi  how r u? what's your email id?"
starts_with = text.startswith('hi')
ends_with = text.endswith('?')

# %%
print(starts_with)
# Out:
# True

# %%
print(ends_with)
# Out:
# True

# %%
mails =['john.doe123@example.com','sarah.smith456@example.com','michael.brown789@example.com','emily.johnson001@example.com',
        'david.wilson202@example.com','olivia.martin303@example.com','james.taylor404@example.com','sophia.anderson505@example.com',
        'daniel.thomas606@example.com','ava.jackson707@example.com']

# %%
list = []
for i in mails:
    if i.endswith('@example.com'):
        list.append(i)
print(list)
# Out:
# ['john.doe123@example.com', 'sarah.smith456@example.com', 'michael.brown789@example.com', 'emily.johnson001@example.com', 'david.wilson202@example.com', 'olivia.martin303@example.com', 'james.taylor404@example.com', 'sophia.anderson505@example.com', 'daniel.thomas606@example.com', 'ava.jackson707@example.com']

# %%
print([i for i in mails if i.endswith('@example.com')])
# Out:
# ['john.doe123@example.com', 'sarah.smith456@example.com', 'michael.brown789@example.com', 'emily.johnson001@example.com', 'david.wilson202@example.com', 'olivia.martin303@example.com', 'james.taylor404@example.com', 'sophia.anderson505@example.com', 'daniel.thomas606@example.com', 'ava.jackson707@example.com']

# %% [markdown]
# findstrg  -- preffered over

# %%
strg = 'hello welcome to disney world'
position= strg.find('o')
print(position)
# Out:
# 4

# %% [markdown]
# index

# %%
strg = 'hello welcome to disney world'
position= strg.index('o')
print(position)
# Out:
# 4

# %% [markdown]
# isdigit

# %%
strg = 'hello'
num ="123245"
numeric = num.isdigit()
alphabetic= strg.isalpha()
print(alphabetic)
print(numeric)
# Out:
# True
# True

# %% [markdown]
# join - converts list of substrings into string

# %%
list_substrings = ['hello', 'python world']
strings = ' '.join(list_substrings)
strings
# Out:
# 'hello python world'

# %%
fist_word2capital_ltr = 'hi my name is color and i am colouful'
result = fist_word2capital_ltr.title()
result
# Out:
# 'Hi My Name Is Color And I Am Colouful'
